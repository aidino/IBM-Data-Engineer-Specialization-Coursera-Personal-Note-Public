# %% [markdown]
# # Spiders

# %%
# Import scrapy
import scrapy

# Import the CrawlerProcess: for running the spider
from scrapy.crawler import CrawlerProcess

# Create the Spider class
class DC_Chapter_Spider(scrapy.Spider):
  name = "dc_chapter_spider"
  # start_requests method
  def start_requests(self):
    yield scrapy.Request(url = url_short,
                         callback = self.parse_front)
  # First parsing method
  def parse_front(self, response):
    course_blocks = response.css('div.course-block')
    course_links = course_blocks.xpath('./a/@href')
    links_to_follow = course_links.extract()
    for url in links_to_follow:
      yield response.follow(url = url,
                            callback = self.parse_pages)
  # Second parsing method
  def parse_pages(self, response):
    crs_title = response.xpath('//h1[contains(@class,"title")]/text()')
    crs_title_ext = crs_title.extract_first().strip()
    ch_titles = response.css('h4.chapter__title::text')
    ch_titles_ext = [t.strip() for t in ch_titles.extract()]
    dc_dict[ crs_title_ext ] = ch_titles_ext

url_short = 'https://assets.datacamp.com/production/repositories/2560/datasets/19a0a26daa8d9db1d920b5d5607c19d6d8094b3b/all_short'

# Initialize the dictionary **outside** of the Spider class
dc_dict = dict()

# Run the Spider
process = CrawlerProcess()
process.crawl(DC_Chapter_Spider)
process.start()

# Print a preview of courses
# previewCourses(dc_dict)
# Out:
# 2023-08-23 14:33:50 [scrapy.utils.log] INFO: Scrapy 2.10.0 started (bot: scrapybot)
# 2023-08-23 14:33:50 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.9.17 (main, Jul  5 2023, 20:41:20) - [GCC 11.2.0], pyOpenSSL 23.2.0 (OpenSSL 3.1.2 1 Aug 2023), cryptography 41.0.3, Platform Linux-6.4.10-200.fc38.x86_64-x86_64-with-glibc2.37
# 2023-08-23 14:33:50 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-08-23 14:33:50 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-08-23 14:33:50 [py.warnings] WARNING: /home/mpp/.conda/envs/data-engineering/lib/python3.9/site-packages/scrapy/utils/request.py:248: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-08-23 14:33:50 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2023-08-23 14:33:50 [scrapy.extensions.telnet] INFO: Telnet Password: 333131c11d1c0d19
# 2023-08-23 14:33:50 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-08-23 14:33:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-08-23 14:33:50 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-08-23 14:33:50 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-08-23 14:33:50 [scrapy.core.engine] INFO: Spider opened
# 2023-08-23 14:33:50 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-08-23 14:33:50 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-08-23 14:33:50 [scrapy.core.engine] ERROR: Error while obtaining start requests
# Traceback (most recent call last):
#   File "/home/mpp/.conda/envs/data-engineering/lib/python3.9/site-packages/scrapy/core/engine.py", line 180, in _next_request
#     request = next(self.slot.start_requests)
#   File "/tmp/ipykernel_35265/2121648284.py", line 12, in start_requests
#     yield scrapy.Request(url = url_short,
# NameError: name 'url_short' is not defined
# 2023-08-23 14:33:50 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-08-23 14:33:50 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'elapsed_time_seconds': 0.002238,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 8, 23, 7, 33, 50, 578975),
#  'log_count/DEBUG': 1,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 199659520,
#  'memusage/startup': 199659520,
#  'start_time': datetime.datetime(2023, 8, 23, 7, 33, 50, 576737)}
# 2023-08-23 14:33:50 [scrapy.core.engine] INFO: Spider closed (finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/mpp/Documents/IBM-Data-Engineer-Specialization-Coursera-Personal-Note-Public/web-scraping-python/spiders.ipynb Cell 2 line 3
#      <a href='vscode-notebook-cell:/home/mpp/Documents/IBM-Data-Engineer-Specialization-Coursera-Personal-Note-Public/web-scraping-python/spiders.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a> process.start()
#      <a href='vscode-notebook-cell:/home/mpp/Documents/IBM-Data-Engineer-Specialization-Coursera-Personal-Note-Public/web-scraping-python/spiders.ipynb#W0sZmlsZQ%3D%3D?line=37'>38</a> # Print a preview of courses
# ---> <a href='vscode-notebook-cell:/home/mpp/Documents/IBM-Data-Engineer-Specialization-Coursera-Personal-Note-Public/web-scraping-python/spiders.ipynb#W0sZmlsZQ%3D%3D?line=38'>39</a> previewCourses(dc_dict)
#
# NameError: name 'previewCourses' is not defined
